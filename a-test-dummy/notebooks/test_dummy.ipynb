# %%
# This only runs on first call, but will confirm that my EDA Libraries have loaded appropriately. 
# General Requirements: setup_env.py, requirements.txt, and all appropriate libraries installed.

import testers.dsc_eda_tester.setup_env as setup_env


# To run it again manually:
#setup_env.eda_system_status()
