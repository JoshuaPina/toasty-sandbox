# %%
import sys
import config

# Project Root
PROJECT_ROOT = config.PROJECT_ROOT
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
from tools import eda_function_guide
# List just the tools
eda_function_guide.list_tools()
# Out:
# Available Tool Modules:
#   • check_eda_env (1 functions)
#   • eda_crime_analysis (3 functions)
#   • eda_data_quality (3 functions)
#   • eda_feature_engineering (4 functions)
#   • eda_starter (8 functions)

# %%
# Import Tools
from tools import check_eda_env, eda_starter

# Check EDA Environment
eda_starter.set_styles() # Set Global Config
check_eda_env.eda_env() # Check EDA Environment for essential packages
# Now you can proceed with your EDA tasks using the available tools
# Out:
# Visual styles set.
#            Phase 1: Data Cleaning & EDA Environment
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┓
# ┃ Library              ┃ Category        ┃   Version ┃ Status ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━┩
# │ Pandas               │ Dataframes      │     2.3.3 │   ✔    │
# │ NumPy                │ Math            │     2.3.5 │   ✔    │
# │ Rich                 │ UI              │ Installed │   ✔    │
# │ TQDM                 │ Utils           │    4.67.1 │   ✔    │
# │ GeoPandas            │ Spatial         │     1.1.1 │   ✔    │
# │ Shapely              │ Geometry        │     2.1.2 │   ✔    │
# │ Matplotlib           │ Visualization   │    3.10.6 │   ✔    │
# │ Seaborn              │ Visualization   │    0.13.2 │   ✔    │
# │ Missingno            │ Data Cleaning   │     0.5.2 │   ✔    │
# │ SciPy                │ Statistics      │    1.16.2 │   ✔    │
# │ Scikit-Learn         │ Imputation      │     1.7.2 │   ✔    │
# ...

# %%
"""

# Display Available Tools in a Table
# ---- I should probably make this its own script at some point ----
from rich.console import Console
from rich.table import Table
from rich.panel import Panel

console = Console()

table = Table(show_header=True, header_style="bold magenta")
table.add_column("Tool/Script", style="dim", width=15)
table.add_column("Category", style="italic", width=10)
table.add_column("Function", style="italic", width=25)
table.add_column("Description", style="bold cyan", justify="right")

table.add_row("check_eda_env", "Env Setup", "eda_env()", "Check EDA Environment for essential packages")
table.add_row("eda_starter", "EDA Util", "set_styles()", "Set Global Config")
table.add_row("eda_starter", "EDA Util", "check_missing(df)", "Check for missing values in DF")
table.add_row("eda_starter", "EDA Util", "visualize_missing(df)", "Visualize missing data patterns in DF")
table.add_row("eda_starter", "EDA Util", "check_sparsity(df)", "Check DF to determine if 0-inflated")
table.add_row("eda_starter", "EDA Util", "plot_correlation(df)", "Plot correlation mat for num-features in DF")
table.add_row("eda_starter", "EDA Util", "inspect_categories(df)", "Shows top values for cat-features (NPU, Zone)")
table.add_row("eda_starter", "EDA Util", "plot_distributions(df)", "Plots histograms for numerical data") 
table.add_row("eda_starter", "EDA Util", "plot_boxplots(df)", "Plots boxplots for num-data to identify outliers")


console.print(Panel(table, title="Available Tools in 'tools' Folder", subtitle="Function Key"))"""
